# %%
# %pip install -U kaleido
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json
import copy
import significantdigits as sd

# %%
Results_tableNoConf=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/IEEE/Results_tableNoConf_IEEE.pkl')
Results_tableWConf=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/IEEE/Results_tableWConf_IEEE.pkl')

# Result_Noconf_MCA=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableNoConf_batch1.pkl')
# Result_Wconf_MCA= pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableWConf_batch1.pkl')
# Results_Wconf =pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableNoConf_batch1.pkl')
# Results_Noconf=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableWConf_batch1.pkl')
Resulthc_Noconf_MCA=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/batchhc/Results_tableNoConf.pkl')
Resulthc_Wconf_MCA=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/batchhc/Results_tableWConf.pkl')

Results_tableNoConf=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableNoConf.pkl')
Results_tableWConf=pd.read_pickle('/home/ubuntu/Desktop/Thesis/overlap/allbatches/Result_tableWConf.pkl')
subjects_to_remove = ['sub-172260', 'sub-43046', 'sub-43045', 'sub-116870', 'sub-160040', 'sub-168195',  'sub-162941', 'sub-156734', 'sub-140041']#they have RLSplit so has been removed 
Results_Wconf = Results_tableWConf[~Results_tableWConf['subject'].isin(subjects_to_remove)]
Results_Noconf= Results_tableNoConf[~Results_tableNoConf['subject'].isin(subjects_to_remove)]

# %%
Results_Noconf
# Out:
#          subject session repetition   acquisition  \
# 0     sub-100842       3      rep-1  acq-PARepeat
# 1     sub-100842       3      rep-1        acq-PA
# 2     sub-100842       1      rep-1        acq-RL
# 3     sub-100842       2      rep-1        acq-RL
# 4     sub-100842       3      rep-2        acq-PA
# ...          ...     ...        ...           ...
# 2561  sub-170793       1      rep-6        acq-RL
# 2562  sub-170793       1      rep-7        acq-RL
# 2563  sub-170793       1      rep-8        acq-RL
# 2564  sub-170793       1      rep-9        acq-RL
# 2565  sub-170793       1     rep-10        acq-RL
#
#                                     degree_centralities  \
# 0     {0: 0.9494949494949496, 1: 0.98989898989899, 2...
# 1     {0: 0.9494949494949496, 1: 0.98989898989899, 2...
# 2     {0: 0.9595959595959597, 1: 1.0, 2: 0.989898989...
# 3     {0: 0.9797979797979799, 1: 1.0, 2: 0.959595959...
# 4     {0: 0.9494949494949496, 1: 0.9797979797979799,...
# ...

# %%
def makestedvAnat_metric(df):
    """
    Calculate standard deviation of network metrics across subjects for each repetition, session, and acquisition.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe containing network metrics for different subjects, sessions, acquisitions and repetitions
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with standard deviations of metrics for each repetition, session, and acquisition
    """
    # Define columns for metrics
    metric_columns = [
        'degree_(AnatomicalVar)', 'betweeness_(AnatomicalVar)', 
        'clusteringcoef_(AnatomicalVar)', 'eigenvec_(AnatomicalVar)', 
        'smallworldness(AnatomicalVar)', 'avg_shortestPathLength(AnatomicalVar)'
    ]
    subject_ids=[]
    # Info columns
    info_columns = ['iteration', 'session', 'acquisition']
    
    # Pre-filter to exclude unwanted acquisitions for efficiency
    df_filtered = df[~df['acquisition'].isin(['acq-RLsplit1', 'acq-LRsplit1'])]
    
    # Create empty list to collect results
    results = []
    
    # First loop through repetitions (since we want to group by repetition)
    for rep in range(1, 2):
        rep_str = f'rep-{rep}'
        # Filter for current repetition
        rep_df = df_filtered[df_filtered['repetition'] == rep_str]
        print(rep_str)
        if rep_df.empty:
            continue
            
        # Group by session and acquisition
        for (session, acquisition), group in rep_df.groupby(['session', 'acquisition']):
            # Collections for metrics across subjects
            all_metrics = {
                'degree': [], 'betweeness': [], 'eigen': [], 
                'clustering': [], 'smallworld': [], 'shortestpath': []
            }
            # Loop through subjects in this group
            for subject, subject_data in group.groupby('subject'):
                if subject_data.empty:
                    continue
                # Get the first (and should be only) row for this subject in this repetition/session/acquisition
                row = subject_data.iloc[0]
                # if ((session=='1') & (acquisition=='acq-RL')):
                #     print(subject)
                if (session=='1') &(acquisition=='acq-RL'):
                    subject_ids.append(subject)                # Check if required data exists
                if (isinstance(row.get('degree_centralities'), dict) and 
                    isinstance(row.get('betweenness_centralities'), dict) and
                    isinstance(row.get('eigenvector_centralities'), dict) and
                    isinstance(row.get('clustering_coefficients'), dict)):
                    
                    # Extract metrics
                    all_metrics['degree'].append(list(row['degree_centralities'].values()))
                    all_metrics['betweeness'].append(list(row['betweenness_centralities'].values()))
                    all_metrics['eigen'].append(list(row['eigenvector_centralities'].values()))
                    all_metrics['clustering'].append(list(row['clustering_coefficients'].values()))
                    
                    # Add scalar metrics if they exist
                    if 'small_worldness' in row:
                        all_metrics['smallworld'].append(row['small_worldness'])
                    if 'avg_shortest_path_length' in row:
                        all_metrics['shortestpath'].append(row['avg_shortest_path_length'])
            # Only calculate stats if we have enough data (at least 2 subjects)
            if len(all_metrics['degree']) < 2:
                continue
                
            # Calculate standard deviations
            result_row = {
                'iteration': f'iter_{rep}',
                'session': session,
                'acquisition': acquisition,
                'degree_(AnatomicalVar)': all_metrics['degree'],
                'betweeness_(AnatomicalVar)': all_metrics['betweeness'],
                # Note: Fixed a bug in the original code - eigenvec and clusteringcoef were swapped
                'eigenvec_(AnatomicalVar)': all_metrics['eigen'],
                'clusteringcoef_(AnatomicalVar)': all_metrics['clustering']
            }
            
            # Add scalar metrics if available
            if all_metrics['smallworld']:
                result_row['smallworldness(AnatomicalVar)'] = np.std(all_metrics['smallworld'], axis=0)
            if all_metrics['shortestpath']:
                result_row['avg_shortestPathLength(AnatomicalVar)'] = np.std(all_metrics['shortestpath'], axis=0)
                
            results.append(result_row)
    
    # Create DataFrame from results
    avrofStd_BetweenSubject = pd.DataFrame(results)
    
    # Ensure proper data types for object columns
    for col in metric_columns:
        if col in avrofStd_BetweenSubject.columns:
            avrofStd_BetweenSubject[col] = avrofStd_BetweenSubject[col].astype('object')
    
    return avrofStd_BetweenSubject,subject_ids

# %%
Results_Noconf[(Results_Noconf['acquisition']=='acq-RL') & (Results_Noconf['session']=='1') &(Results_Noconf['subject']=='sub-166701')]
# Out:
#          subject session repetition acquisition  \
# 2416  sub-166701       1      rep-1      acq-RL
# 2417  sub-166701       1      rep-2      acq-RL
# 2418  sub-166701       1      rep-3      acq-RL
# 2419  sub-166701       1      rep-4      acq-RL
# 2420  sub-166701       1      rep-5      acq-RL
# 2421  sub-166701       1      rep-6      acq-RL
# 2422  sub-166701       1      rep-7      acq-RL
# 2423  sub-166701       1      rep-8      acq-RL
# 2424  sub-166701       1      rep-9      acq-RL
# 2425  sub-166701       1     rep-10      acq-RL
#
#                                     degree_centralities  \
# 2416  {0: 0.8686868686868687, 1: 0.8585858585858587,...
# 2417  {0: 0.8686868686868687, 1: 0.8585858585858587,...
# 2418  {0: 0.8686868686868687, 1: 0.8686868686868687,...
# 2419  {0: 0.8787878787878789, 1: 0.8585858585858587,...
# 2420  {0: 0.8686868686868687, 1: 0.8585858585858587,...
# 2421  {0: 0.8686868686868687, 1: 0.8686868686868687,...
# ...

# %%
b1_no,subject_idsb1=makestedvAnat_metric(Results_Noconf[Results_Noconf['repetition']=='rep-1'])
hc_no,subject_idshc=makestedvAnat_metric(Resulthc_Noconf_MCA[Resulthc_Noconf_MCA['repetition']=='rep-1'])
np.array(b1_no.iloc[3]['degree_(AnatomicalVar)']).shape
len(subject_idsb1)
# Out:
# rep-1
# rep-1
# 108

# %%
dfpd_values = np.array(b1_no.iloc[3]['degree_(AnatomicalVar)'])

dfpd_values.shape[0]
# Out:
# 108

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

def plot_dist(dfpd, dfhc, metric,subjb1,subjhc):
    subject_idsb1=subjb1
    subject_idshc=subjhc
    dfpd_values = np.array(dfpd.iloc[3][metric])
    dfhc_values = np.array(dfhc.iloc[0][metric])
    num_regions = dfpd_values.shape[1]
    regions_per_plot = 25
    num_subplots = num_regions // regions_per_plot
    region_labels = [f"R{i+1}" for i in range(num_regions)]

    fig = make_subplots(
        rows=num_subplots, cols=1, shared_yaxes=True,
        vertical_spacing=0.08
    )

    for region in range(num_regions):
        subplot_row = region // regions_per_plot + 1
        region_in_subplot = region % regions_per_plot
        pos_conf = region_in_subplot - 0.2
        pos_no_conf = region_in_subplot + 0.2

        # PD box
    #     fig.add_trace(go.Box(
    #         y=dfpd_values[:, region],
    #         x=[pos_conf] * dfpd_values.shape[0],
    #         name="PD" if region == 0 else None,
    #         marker_color="green",
    #         boxpoints='suspectedoutliers',
    #         legendgroup="PD",
    #         showlegend=(region == 0),
    #         line=dict(width=1),
    #         opacity=0.7,
    #         text=[region_labels[region]] * dfpd_values.shape[0],
    #         hovertemplate="<b>Region:</b> %{text}<br><b>Value:</b> %{y}<br><extra>PD</extra>"
    #     ), row=subplot_row, col=1)
    #    fig.add_trace(go.Box(
    #         y=dfhc_values[:, region],
    #         x=[pos_no_conf] * dfhc_values.shape[0],
    #         name="HC" if region == 0 else None,
    #         marker_color="red",
    #         boxpoints='suspectedoutliers',
    #         legendgroup="HC",
    #         showlegend=(region == 0),
    #         line=dict(width=1),
    #         opacity=0.7,
    #         text=[region_labels[region]] * dfhc_values.shape[0],
    #         hovertemplate="<b>Region:</b> %{text}<br><b>Value:</b> %{y}<br><extra>HC</extra>"
    #     ), row=subplot_row, col=1)
       # PD box
        fig.add_trace(go.Scatter(
            y=dfpd_values[:, region],
            x=[pos_conf] * len(dfpd_values[:, region]),
            name="PD" if region == 0 else None,
            mode="markers",
            marker=dict(
                size=3,
                color="green",
                opacity=0.5
            ),
            legendgroup="PD",
            showlegend=(region == 0),
            text=[f"{subject_idsb1[i]}" for i in range(dfpd_values.shape[0])],
            hovertemplate="<b>%{text}</b><br><b>Value:</b> %{y}<br><extra>PD</extra>"
        ), row=subplot_row, col=1)
       # HC box
        fig.add_trace(go.Scatter(
            y=dfhc_values[:, region],
            x=[pos_no_conf] * len(dfhc_values[:, region]),
            name="HC" if region == 0 else None,
            mode="markers",
            marker=dict(
                size=3,
                color="red",
                opacity=0.5
            ),
            legendgroup="HC",
            showlegend=(region == 0),
            text=[f"{subject_idshc[i]}" for i in range(dfhc_values.shape[0])],
            hovertemplate="<b>Region:</b> %{text}<br><b>Value:</b> %{y}<br><extra>HC</extra>"
        ), row=subplot_row, col=1)
 

    fig.update_layout(
        title=f"Distribution of {metric} Centrality values Across {num_regions} Regions",
        height=200 * num_subplots,
        width=1800,
        showlegend=True,
        legend=dict(orientation="h", yanchor="bottom", y=1.02, xanchor="center", x=0.5),
        margin=dict(b=100)
    )

    for i in range(1, num_subplots + 1):
        start_region = regions_per_plot * (i - 1)
        end_region = min(regions_per_plot * i, num_regions)
        tickvals = list(range(regions_per_plot))
        ticktext = [f"R{j+1}" for j in range(start_region, end_region)]

        fig.update_xaxes(
            row=i, col=1,
            tickmode='array',
            tickvals=tickvals,
            ticktext=ticktext,
            tickangle=45,
            showticklabels=True,
            title_text="Brain Region" if i == num_subplots else ""
        )
        fig.update_yaxes(
            title_text=f"{metric} Centrality" if i == 1 else "",
            row=i, col=1
        )

    fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='rgba(34,139,34,0.2)')
    fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='rgba(178,34,34,0.2)')

    return fig

# %%
plot_dist(b1_no,hc_no,'clusteringcoef_(AnatomicalVar)',subject_idsb1, subject_idshc) #eigenvec_(AnatomicalVar)	 betweeness_(AnatomicalVar)

# %%
hc_no
# Out:
#   iteration session acquisition  \
# 0    iter_1       1      acq-RL
#
#                               degree_(AnatomicalVar)  \
# 0  [[0.98989898989899, 0.9696969696969697, 0.9797...
#
#                           betweeness_(AnatomicalVar)  \
# 0  [[0.0007990533628469557, 0.0007257632425539038...
#
#                             eigenvec_(AnatomicalVar)  \
# 0  [[0.10555158032566574, 0.10359846363085504, 0....
#
#                       clusteringcoef_(AnatomicalVar)  \
# 0  [[0.934146854618136, 0.9375, 0.936211340206185...
#
#   smallworldness(AnatomicalVar) avg_shortestPathLength(AnatomicalVar)
# 0                      0.005621                              0.027049

# %%
def compute_ttest(dfpd,dfhc,metric):
    import numpy as np
    import pandas as pd
    from scipy.stats import ttest_ind
    from statsmodels.stats.multitest import multipletests
    from scipy.stats import ks_2samp

    dfpd_values = np.array(dfpd.iloc[3][metric])
    dfhc_values = np.array(dfhc.iloc[0][metric])

    num_regions = dfpd_values.shape[1]
    p_values = []

    for region in range(num_regions):
        # Welch's t-test (does not assume equal variance)
        stat, p = ttest_ind(dfpd_values[:, region], dfhc_values[:, region], equal_var=False)
        p_values.append(p)

    p_values = np.array(p_values)
    # FDR correction (Benjamini-Hochberg)
    reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')
    return reject,pvals_corrected

# %%
hc_no
# Out:
#   iteration session acquisition  \
# 0    iter_1       1      acq-RL
#
#                               degree_(AnatomicalVar)  \
# 0  [[0.98989898989899, 0.9696969696969697, 0.9797...
#
#                           betweeness_(AnatomicalVar)  \
# 0  [[0.0007990533628469557, 0.0007257632425539038...
#
#                             eigenvec_(AnatomicalVar)  \
# 0  [[0.10555158032566574, 0.10359846363085504, 0....
#
#                       clusteringcoef_(AnatomicalVar)  \
# 0  [[0.934146854618136, 0.9375, 0.936211340206185...
#
#   smallworldness(AnatomicalVar) avg_shortestPathLength(AnatomicalVar)
# 0                      0.005621                              0.027049

# %%
def compute_ks_test(dfpd, dfhc, metric):
    import numpy as np
    from scipy.stats import ks_2samp
    from statsmodels.stats.multitest import multipletests

    dfpd_values = np.array(dfpd.iloc[3][metric])
    dfhc_values = np.array(dfhc.iloc[0][metric])

    num_regions = dfpd_values.shape[1]
    p_values = []
    for region in range(num_regions):
        # Kolmogorov-Smirnov test (directional)
        stat_value, p_val = ks_2samp(dfpd_values[:, region], dfhc_values[:, region], alternative='alternative')
        p_values.append(p_val)
    p_values = np.array(p_values)
    # FDR correction (Benjamini-Hochberg)
    reject, pvals_corrected, _, _ = multipletests(p_values, alpha=0.05, method='fdr_bh')
    return reject, pvals_corrected

r,p=compute_ttest(b1_no,hc_no,'clusteringcoef_(AnatomicalVar)')
# r,p=compute_ks_test(b1_no,hc_no,'clusteringcoef_(AnatomicalVar)')

print(r,p)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False] [0.38002106 0.38002106 0.44676472 0.38002106 0.38002106 0.38002106
#  0.38002106 0.38002106 0.38002106 0.38002106 0.38002106 0.38002106
#  0.38002106 0.38002106 0.38002106 0.38002106 0.38002106 0.38002106
#  0.38002106 0.38002106 0.38002106 0.38002106 0.38002106 0.38002106
#  0.38002106 0.38002106 0.38002106 0.38002106 0.38002106 0.38002106
# ...

# %%
hc_no_arE=np.array(hc_no.iloc[0]['eigenvec_(AnatomicalVar)'])
arr = np.mean(hc_no_arE, axis=1)  # shape (N,)
min_indices = np.argsort(arr)[:5]
min_indices
# (np.mean(hc_no_arE, axis=1)).argmin()
# hc_no_arE[28]
# Out:
# array([28, 15, 23, 10,  1])

# %%
CM_maxE_C=Resulthc_Noconf_MCA[(Resulthc_Noconf_MCA['repetition']=='rep-1') & (Resulthc_Noconf_MCA['acquisition']=='acq-RL') & (Resulthc_Noconf_MCA['session']=='1') & (Resulthc_Noconf_MCA['subject']=='sub-103183')]['correlation_matrix'].values[0]
CM_min_E=Resulthc_Noconf_MCA[(Resulthc_Noconf_MCA['repetition']=='rep-1') & (Resulthc_Noconf_MCA['acquisition']=='acq-RL') & (Resulthc_Noconf_MCA['session']=='1') & (Resulthc_Noconf_MCA['subject']=='sub-118726')]['correlation_matrix'].values[0]
CM_min_C=Resulthc_Noconf_MCA[(Resulthc_Noconf_MCA['repetition']=='rep-1') & (Resulthc_Noconf_MCA['acquisition']=='acq-RL') & (Resulthc_Noconf_MCA['session']=='1') & (Resulthc_Noconf_MCA['subject']=='sub-142086')]['correlation_matrix'].values[0]

# %%
def plot(CM):
    from nilearn import datasets, plotting, image
    import numpy as np
    atlas = datasets.fetch_atlas_schaefer_2018(n_rois=100, yeo_networks=7)
    atlas.labels=atlas.labels.tolist()
    atlas_labels = [label.decode('utf-8') for label in atlas.labels]
    fig = plotting.plot_matrix(
        CM, title='FC', figure=(8, 8),
        labels=atlas_labels, vmax=0.8, vmin=-0.8, reorder=False
    )
plot(CM_maxE_C)
plot(CM_min_E)
plot(CM_min_C)
